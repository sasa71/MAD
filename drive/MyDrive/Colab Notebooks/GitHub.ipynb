# %%
# !git version
# Out:
# git version 2.25.1

# %%
# !git config --global user.email "salva.russo10@gmail.com"

# !git config --global user.name "sasa71"

# %%
# !git clone https://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@github.com/sasa71/MAD.git
# Out:
# Cloning into 'MAD'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 21 (delta 3), reused 11 (delta 1), pack-reused 0
# Unpacking objects: 100% (21/21), 23.55 KiB | 3.36 MiB/s, done.

# %%
# !git add .
# !git commit -m "fratm"
# !git push
# Out:
# [main 93dd6e3] fratm
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  delete mode 100644 immagini bona fide/bbbb
#  delete mode 100644 immagini morphate/aaaa
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 216 bytes | 216.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sasa71/MAD.git
#    4440a31..93dd6e3  main -> main
